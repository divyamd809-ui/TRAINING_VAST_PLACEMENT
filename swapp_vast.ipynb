# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamd809-ui/TRAINING_VAST_PLACEMENT/blob/main/swapp_vast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Using Temp")
a,b=10,5
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=10,5
a,b=b,a
print(a,b)
print("Using + and -")
a,b=10,5
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=10,5
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 5 10
# Using ,
# 5 10
# Using + and -
# 5 10
# Using ^
# 5 10
