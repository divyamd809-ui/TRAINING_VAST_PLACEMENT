# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamd809-ui/TRAINING_VAST_PLACEMENT/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

print("Smallest element:", max(numbers))
# Out:
# Enter numbers: 1 34 56
# Smallest element: 56

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range (n):
  m = int(input("enter the element"))
  a.append(m)

  print(a)
print("the smallest element is",min(a))
# Out:
# enter the number of elements7
# enter the element1
# [1]
# enter the element3
# [1, 3]
# enter the element5
# [1, 3, 5]
# enter the element8
# [1, 3, 5, 8]
# enter the element9
# [1, 3, 5, 8, 9]
# enter the element8
# [1, 3, 5, 8, 9, 8]
# enter the element1
# [1, 3, 5, 8, 9, 8, 1]
# the smallest element is 1

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range (n):
  m = int(input("enter the element"))
  a.append(m)

  print(a)
print("the smallest element is",max(a))
# Out:
# enter the number of elements3
# enter the element5
# [5]
# enter the element6
# [5, 6]
# enter the element7
# [5, 6, 7]
# the smallest element is 7

# %%
n = int (input("enter the number of elenments :"))
a =[]
for i in range(n):
    m = int(input("enter the element"))
    a.append(m)
print(a)
# Out:
# enter the number of elenments : 6
# enter the element12
# enter the element34
# enter the element56
# enter the element28
# enter the element54
# enter the element28
# [12, 34, 56, 28, 54, 28]

# %%
n= int(input("enter the number of elements:"))
a =[]

for i in range(n):
  m = int(input("enter the element:"))
  a.append(m)
print(a)
print( "The sum of elements is",sum(a))
# Out:
# enter the number of elements:5
# enter the element:12
# enter the element:23
# enter the element:34
# enter the element:45
# enter the element:56
# [12, 23, 34, 45, 56]
# The sum of elements is 170

# %%
#reverse of an array

n = int(input("Enter the number of elements: "))
a = []

for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)

print("Original list:", a)
print("Reversed list:", a[::-1])
# Out:
# Enter the number of elements: 12
# Enter the element: 12
# Enter the element: 23
# Enter the element: 4
# Enter the element: 5
# Enter the element: 6
# Enter the element: 7
# Enter the element: 8
# Enter the element: 9
# Enter the element: 12
# Enter the element: 90
# Enter the element: 28
# Enter the element: 54
# Original list: [12, 23, 4, 5, 6, 7, 8, 9, 12, 90, 28, 54]
# Reversed list: [54, 28, 90, 12, 9, 8, 7, 6, 5, 4, 23, 12]

# %%
n = int(input("Enter the number of elements: "))
a = []

for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)

print("List:", a)

x = int(input("Enter the number to search for: "))

if x in a:
    print(x, "exists in the list")
else:
    print(x, "does not exist in the list")
# Out:
# Enter the number of elements: 4
# Enter the element: 45
# Enter the element: 65
# Enter the element: 76
# Enter the element: 89
# List: [45, 65, 76, 89]
# Enter the number to search for: 76
# 76 exists in the list

# %%
n= int(input("enter the number of element:"))
a =[]
for i in range (n):
    m=int(input("enter the element"))
    a.append(m)
print("list:",a)
x= int(input("enter the number to count"))
print(x, "occur" ,a.count(x), "times")
# Out:
# enter the number of element:4
# enter the element3
# enter the element2
# enter the element4
# enter the element3
# list: [3, 2, 4, 3]
# enter the number to count3
# 3 occur 2 times

# %%
n = int(input("Enter the number of elements: "))
a = []

for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)

print("Original list:", a)

result = []
for num in a:
    if num not in result:
        result.append(num)

print("List after removing duplicates:", result)
# Out:
# Enter the number of elements: 6
# Enter the element: 4
# Enter the element: 5
# Enter the element: 3
# Enter the element: 3
# Enter the element: 4
# Enter the element: 5
# Original list: [4, 5, 3, 3, 4, 5]
# List after removing duplicates: [4, 5, 3]

# %%
n=int(input("enter the number of elements:"))
a =[]
for i in range(n):
  m=int(input("enter the element:"))
  a.append(m)
print("original list:", a)
a.sort()
print("sorted list(asending):" , a)
# Out:
# enter the number of elements:5
# enter the element:7
# enter the element:9
# enter the element:0
# enter the element:2
# enter the element:4
# original list: [7, 9, 0, 2, 4]
# sorted list(asending): [0, 2, 4, 7, 9]

# %%
a=list(map(int,input("enter numbers separated by spaces:").split()))
print("the list is:",a)
# Out:
# enter numbers separated by spaces:1 2 3 4 5 6 7 8 9 0
# the list is: [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
a=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a.append(int(input("Enter the element: ")))
  print("List=",a)
print("Normal slicing without range",a[:])
print("slicing range in leftside",a[1:])
print("slicing with range in both side",a[2:4])
print("slicing with range in rightside",a[:5])
print("slicing using step",a[1:7:3])
# Out:
# Enter the number of elements: 3
# Enter the element: 3
# List= [3]
# Enter the element: 4
# List= [3, 4]
# Enter the element: 4
# List= [3, 4, 4]
# Normal slicing without range [3, 4, 4]
# slicing range in leftside [4, 4]
# slicing with range in both side [4]
# slicing with range in rightside [3, 4, 4]
# slicing using step [4]

# %%
n = int(input("Enter the number of elements: "))
a = []

for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)

print("List:", a)

largest = second = float('-inf')

for num in a:
    if num > largest:
        second = largest
        largest = num
    elif num > second and num != largest:
        second = num

print("The largest is", largest)
print("The second largest is", second)
# Out:
# Enter the number of elements: 4
# Enter the element: 2
# Enter the element: 3
# Enter the element: 4
# Enter the element: 5
# List: [2, 3, 4, 5]
# The largest is 5
# The second largest is 4

# %%
num = int(input("Enter a number: "))
reversed_num = 0
while num > 0:
    digit = num % 10
    reversed_num = reversed_num * 10 + digit
    num //= 10
print("Reversed number:", reversed_num)
# Out:
# Enter a number: 345
# Reversed number: 543

# %%
n=input("Enter a string ")
print("Input string ",n)
print("Reversed string")
print(n[::-1],end='')
# Out:
# Enter a string ammu
# Input string  ammu
# Reversed string
# umma

# %%
n = input("enter a number:")
print(sum(int(digit)for digit in n))
# Out:
# enter a number:12345
# 15

# %%
n = input("enter a number: ")
print("largest digit:",max(n))
# Out:
# enter a number: 1 3 4 5 6
# largest digit: 6

# %%
n = input("enter a string")
if (n==n[::-1]):
  print("palindrome")
else:
  print("not palindrome")
# Out:
# enter a stringamma
# palindrome

# %%
str=input("Ënter a string:")
print("Length of string with built in:",len(str))
c=0
for i in str:
  c=c+1
print("Length of string without built in:",c)

# %%
a=input("Enter string: ")
b=""
for i in a:
    if i not in b:
        b+=i
print("After removing duplicates: ",b)

# %%
s=input("Ënter a string:")
s1=""
for i in s:
  if(i!=" "):
    s1+=i
print(s1)

# %%
str1 = input("enter first string:")
str2 = input("enter sec string :")
if sorted(str1)==sorted(str2):
   print ("anagram")
else:
  print("not anagram")

# %%
str1 = input("enter first string:")
str2 = input("enter sec string :")
if sorted(str1)==sorted(str2):
   print ("anagram")
else:
  print("not anagram")
